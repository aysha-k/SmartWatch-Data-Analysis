# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/content/Screentime-App-Details.csv')
df
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           54 non-null     object
#  1   Usage          54 non-null     int64
#  2   Notifications  54 non-null     int64
#  3   Times opened   54 non-null     int64
#  4   App            54 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
df.head()
# Out:
#         Date  Usage  Notifications  Times opened        App
# 0 2022-08-26     38             70            49  Instagram
# 1 2022-08-27     39             43            48  Instagram
# 2 2022-08-28     64            231            55  Instagram
# 3 2022-08-29     14             35            23  Instagram
# 4 2022-08-30      3             19             5  Instagram

# %%
app=df.groupby('App')

# %%
app.sum()
# Out:
# <ipython-input-16-ecdb4ea7095f>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#            Usage  Notifications  Times opened
# App
# Instagram    841           1196           883
# Whatsapp    2671           5160          2437

# %%
sns.barplot(data=df,x='App',y='Usage')
# Out:
# <Axes: xlabel='App', ylabel='Usage'>

# %% [markdown]
# From the above results, it is clear that Whatsapp is most used app on the basis of its usage,notification and times opened

# %%
sns.scatterplot(data=df,x='Notifications',y='Times opened')
# Out:
# <Axes: xlabel='Notifications', ylabel='Times opened'>

# %%
px.scatter(df,x='Notifications',y='Times opened',color='App').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,x='Notifications',y='Usage',color='App').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.pairplot(data = df)

# %% [markdown]
# The notifications directly involve the app opening and it's usage.
